# %%
import pandas as pd
import numpy

# %%
a=pd.read_csv("trainss.csv")
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
a.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
a.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a.fillna(a.mean(),inplace=True)

# %%
a.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
a.Cabin.fillna("B42",inplace=True)

# %%
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
a.Embarked.isnull().sum()
# Out:
# 2

# %%
a.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
a.fillna("S",inplace=True)

# %%
a.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Q NO 1: how many passengers survived and how many were kill in number and %

# %%
(a.Survived==1).sum()
# Out:
# 342

# %%
(a.Survived==0).sum()
# Out:
# 549

# %%
(a.Survived==1).mean()
# Out:
# 0.3838383838383838

# %%
(a.Survived==0).mean()
# Out:
# 0.6161616161616161

# %%
d={
    
    
    "Died":[(a.Survived==0).sum()],
    "Survived":[(a.Survived==1).sum()],
    "Died_Percentage":[(a.Survived==0).mean()],
    "Survived_percentage":[(a.Survived==1).mean()]
}

# %%
d=pd.DataFrame(d).T
d
# Out:
#                               0
# Died                 549.000000
# Survived             342.000000
# Died_Percentage        0.616162
# Survived_percentage    0.383838

# %% [markdown]
# # Q NO 2: Does survival had anything to do with the gender,(Survived vs Gender)

# %%
a[["Survived","Sex"]].groupby(["Sex"]).sum()
# Out:
#         Survived
# Sex
# female       233
# male         109

# %%
pd.DataFrame(a[["Survived","Sex"]].value_counts())
# Out:
#                    0
# Survived Sex
# 0        male    468
# 1        female  233
#          male    109
# 0        female   81

# %% [markdown]
# # Q NO 3:Does Survival have any thing to do with the class in which the passenger was trivalling and who survived more !st class 2nd class 3rd class passenger

# %%
a[["Survived","Pclass"]].groupby(["Pclass"]).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.DataFrame(a[["Survived","Pclass"]].value_counts())
# Out:
#                    0
# Survived Pclass
# 0        3       372
# 1        1       136
#          3       119
# 0        2        97
# 1        2        87
# 0        1        80

# %% [markdown]
# # Q NO 4: Which Age group , survived the most kids (1-12),teenager(13-19),youngster (20,30),middle age people (31-50),or elders(50)and above?

# %%
pd.options.display.max_rows=891
f=a[["Survived","Age"]].groupby(["Age"]).sum()
f
# Out:
#            Survived
# Age
# 0.420000          1
# 0.670000          1
# 0.750000          2
# 0.830000          2
# 0.920000          1
# 1.000000          5
# 2.000000          3
# 3.000000          5
# 4.000000          7
# 5.000000          4
# 6.000000          2
# 7.000000          1
# 8.000000          2
# 9.000000          2
# 10.000000         0
# 11.000000         1
# 12.000000         1
# 13.000000         2
# 14.000000         3
# 14.500000         0
# 15.000000         4
# 16.000000         6
# 17.000000         6
# 18.000000         9
# 19.000000         9
# 20.000000         3
# 20.500000         0
# 21.000000         5
# 22.000000        11
# 23.000000         5
# 23.500000         0
# 24.000000        15
# 24.500000         0
# 25.000000         6
# 26.000000         6
# 27.000000        11
# 28.000000         7
# 28.500000         0
# 29.000000         8
# 29.699118        52
# 30.000000        10
# 30.500000         0
# 31.000000         8
# 32.000000         9
# ...
